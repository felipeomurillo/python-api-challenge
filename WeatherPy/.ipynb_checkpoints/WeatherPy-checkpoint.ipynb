# %% [markdown]
# # WeatherPy
# ----
# #### Author: Felipe Murillo
# #### Date: May 1, 2020
# #### Description: Visualize weather of 500+ cities across the world of varying distance from the equator
# #### Inputs:  OpenWeatherMap API (and corresponding key)
# #### Output: ./output_data/cities.csv
# ----

# %% [markdown]
# ### Install citipy module and setup dependencies

# %%
# Install citipy module
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/felipe/opt/anaconda3/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/felipe/opt/anaconda3/lib/python3.7/site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from config import api_key_openWeather

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
city_lat = []
city_long = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        city_lat.append(lat_lng[0])
        city_long.append(lat_lng[1])

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
# Create city weather dataFrame skeleton
city_weather_df = pd.DataFrame({"City":cities})
city_weather_df["City Name"] = ""
city_weather_df["Country"] = ""
city_weather_df["Lng"] = ""
city_weather_df["Lat"] = ""
city_weather_df["Max Temp (F)"] = ""
city_weather_df["Humidity (%)"]=""
city_weather_df["Cloudiness (%)"] = ""
city_weather_df["Wind Speed (mph)"] = ""

city_weather_df.head()
# Out:
#             City City Name Country Lng Lat Max Temp (F) Humidity (%)  \
# 0  alta floresta
# 1      saskylakh
# 2   punta arenas
# 3        wanning
# 4       zhigansk
#
#   Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls and store data into weather dataframe

# %%
# Base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Specify temperature in degrees Celsius rather than Kelvin
units = "imperial"

# Build base query URL
base_url = f"{url}appid={api_key_openWeather}&units={units}&q="

# Use for loop to cycle thru each city
for index, city in city_weather_df.iterrows():

    # Print to screen which city is currently being called
    print(f"Retrieving Results for index: {index}, city: {city.loc['City']}")
    
    # Construct query_url
    query_url = base_url + city.loc["City"]
    
    # Request weather data for desired city
    weather_request = requests.get(query_url).json()
     
    # Extract desired data: 
    # longitude, latitude, temperature (deg F), humidity (%), cloudiness (%), wind speed (mph)
    
    try:
        city_weather_df.loc[index, 'City Name'] = weather_request['name']
        city_weather_df.loc[index, 'Country'] = weather_request['sys']['country']  
        city_weather_df.loc[index, 'Lng'] = weather_request['coord']['lon']
        city_weather_df.loc[index, 'Lat'] = weather_request['coord']['lat']
        city_weather_df.loc[index, 'Max Temp (F)'] = weather_request['main']['temp_max']
        city_weather_df.loc[index, 'Humidity (%)'] = weather_request['main']['humidity']
        city_weather_df.loc[index, 'Cloudiness (%)'] = weather_request['clouds']['all']
        city_weather_df.loc[index, 'Wind Speed (mph)'] = weather_request['wind']['speed']
        
    except (KeyError, IndexError):
        print("City Not Found... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for index: 0, city: alta floresta
# ------------
# Retrieving Results for index: 1, city: saskylakh
# ------------
# Retrieving Results for index: 2, city: punta arenas
# ------------
# Retrieving Results for index: 3, city: wanning
# ------------
# Retrieving Results for index: 4, city: zhigansk
# ------------
# Retrieving Results for index: 5, city: los llanos de aridane
# ------------
# Retrieving Results for index: 6, city: kayerkan
# ------------
# Retrieving Results for index: 7, city: hermanus
# ------------
# Retrieving Results for index: 8, city: sinjah
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 9, city: poshekhonye
# ------------
# Retrieving Results for index: 10, city: seymchan
# ------------
# Retrieving Results for index: 11, city: east london
# ------------
# Retrieving Results for index: 12, city: kilosa
# ------------
# Retrieving Results for index: 13, city: broome
# ------------
# Retrieving Results for index: 14, city: tasiilaq
# ------------
# Retrieving Results for index: 15, city: maine-soroa
# ------------
# Retrieving Results for index: 16, city: albany
# ------------
# Retrieving Results for index: 17, city: busselton
# ------------
# Retrieving Results for index: 18, city: mataura
# ------------
# Retrieving Results for index: 19, city: pandan
# ------------
# Retrieving Results for index: 20, city: castro
# ------------
# Retrieving Results for index: 21, city: santa rosa
# ------------
# Retrieving Results for index: 22, city: guerrero negro
# ------------
# Retrieving Results for index: 23, city: sao filipe
# ------------
# Retrieving Results for index: 24, city: zhigalovo
# ------------
# Retrieving Results for index: 25, city: rikitea
# ------------
# Retrieving Results for index: 26, city: belaya gora
# ------------
# Retrieving Results for index: 27, city: parrita
# ------------
# Retrieving Results for index: 28, city: portland
# ------------
# Retrieving Results for index: 29, city: hasaki
# ------------
# Retrieving Results for index: 30, city: bongandanga
# ------------
# Retrieving Results for index: 31, city: carnarvon
# ------------
# Retrieving Results for index: 32, city: tuatapere
# ------------
# Retrieving Results for index: 33, city: hobart
# ------------
# Retrieving Results for index: 34, city: bulungu
# ------------
# Retrieving Results for index: 35, city: ushuaia
# ------------
# Retrieving Results for index: 36, city: bredasdorp
# ------------
# Retrieving Results for index: 37, city: sakakah
# ------------
# Retrieving Results for index: 38, city: taolanaro
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 39, city: severo-kurilsk
# ------------
# Retrieving Results for index: 40, city: araouane
# ------------
# Retrieving Results for index: 41, city: roebourne
# ------------
# Retrieving Results for index: 42, city: alofi
# ------------
# Retrieving Results for index: 43, city: taoudenni
# ------------
# Retrieving Results for index: 44, city: upernavik
# ------------
# Retrieving Results for index: 45, city: petropavlovsk-kamchatskiy
# ------------
# Retrieving Results for index: 46, city: umzimvubu
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 47, city: soyo
# ------------
# Retrieving Results for index: 48, city: dikson
# ------------
# Retrieving Results for index: 49, city: qaanaaq
# ------------
# Retrieving Results for index: 50, city: isangel
# ------------
# Retrieving Results for index: 51, city: vao
# ------------
# Retrieving Results for index: 52, city: lovozero
# ------------
# Retrieving Results for index: 53, city: saint-philippe
# ------------
# Retrieving Results for index: 54, city: mayo
# ------------
# Retrieving Results for index: 55, city: nanakuli
# ------------
# Retrieving Results for index: 56, city: khani
# ------------
# Retrieving Results for index: 57, city: kapaa
# ------------
# Retrieving Results for index: 58, city: paamiut
# ------------
# Retrieving Results for index: 59, city: impfondo
# ------------
# Retrieving Results for index: 60, city: puerto ayora
# ------------
# Retrieving Results for index: 61, city: zyryanka
# ------------
# Retrieving Results for index: 62, city: king city
# ------------
# Retrieving Results for index: 63, city: port alfred
# ------------
# Retrieving Results for index: 64, city: safaqis
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 65, city: ouro preto do oeste
# ------------
# Retrieving Results for index: 66, city: kemise
# ------------
# Retrieving Results for index: 67, city: jamestown
# ------------
# Retrieving Results for index: 68, city: mumford
# ------------
# Retrieving Results for index: 69, city: urumqi
# ------------
# Retrieving Results for index: 70, city: vaitupu
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 71, city: cabo san lucas
# ------------
# Retrieving Results for index: 72, city: namie
# ------------
# Retrieving Results for index: 73, city: mahebourg
# ------------
# Retrieving Results for index: 74, city: monrovia
# ------------
# Retrieving Results for index: 75, city: attawapiskat
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 76, city: bagrami
# ------------
# Retrieving Results for index: 77, city: bennettsville
# ------------
# Retrieving Results for index: 78, city: ustye
# ------------
# Retrieving Results for index: 79, city: rocha
# ------------
# Retrieving Results for index: 80, city: naantali
# ------------
# Retrieving Results for index: 81, city: niono
# ------------
# Retrieving Results for index: 82, city: aykhal
# ------------
# Retrieving Results for index: 83, city: pallasovka
# ------------
# Retrieving Results for index: 84, city: waddan
# ------------
# Retrieving Results for index: 85, city: fortuna
# ------------
# Retrieving Results for index: 86, city: hithadhoo
# ------------
# Retrieving Results for index: 87, city: krasnokholm
# ------------
# Retrieving Results for index: 88, city: lokosovo
# ------------
# Retrieving Results for index: 89, city: klaksvik
# ------------
# Retrieving Results for index: 90, city: termoli
# ------------
# Retrieving Results for index: 91, city: te anau
# ------------
# Retrieving Results for index: 92, city: praia da vitoria
# ------------
# Retrieving Results for index: 93, city: cap malheureux
# ------------
# Retrieving Results for index: 94, city: salalah
# ------------
# Retrieving Results for index: 95, city: port elizabeth
# ------------
# Retrieving Results for index: 96, city: pirgos
# ------------
# Retrieving Results for index: 97, city: novikovo
# ------------
# Retrieving Results for index: 98, city: makaha
# ------------
# Retrieving Results for index: 99, city: nanortalik
# ------------
# Retrieving Results for index: 100, city: dhamnod
# ------------
# Retrieving Results for index: 101, city: beyneu
# ------------
# Retrieving Results for index: 102, city: marfino
# ------------
# Retrieving Results for index: 103, city: vaini
# ------------
# Retrieving Results for index: 104, city: san isidro
# ------------
# Retrieving Results for index: 105, city: grindavik
# ------------
# Retrieving Results for index: 106, city: berlevag
# ------------
# Retrieving Results for index: 107, city: hambantota
# ------------
# Retrieving Results for index: 108, city: thompson
# ------------
# Retrieving Results for index: 109, city: faanui
# ------------
# Retrieving Results for index: 110, city: sambava
# ------------
# Retrieving Results for index: 111, city: kavieng
# ------------
# Retrieving Results for index: 112, city: dingle
# ------------
# Retrieving Results for index: 113, city: avarua
# ------------
# Retrieving Results for index: 114, city: ancud
# ------------
# Retrieving Results for index: 115, city: moche
# ------------
# Retrieving Results for index: 116, city: lebu
# ------------
# Retrieving Results for index: 117, city: mungaa
# ------------
# Retrieving Results for index: 118, city: cheuskiny
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 119, city: ribeira grande
# ------------
# Retrieving Results for index: 120, city: hilo
# ------------
# Retrieving Results for index: 121, city: sabang
# ------------
# Retrieving Results for index: 122, city: chuy
# ------------
# Retrieving Results for index: 123, city: ola
# ------------
# Retrieving Results for index: 124, city: capreol
# ------------
# Retrieving Results for index: 125, city: khatanga
# ------------
# Retrieving Results for index: 126, city: labuhan
# ------------
# Retrieving Results for index: 127, city: kourou
# ------------
# Retrieving Results for index: 128, city: bambous virieux
# ------------
# Retrieving Results for index: 129, city: clyde river
# ------------
# Retrieving Results for index: 130, city: saleaula
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 131, city: nikolskoye
# ------------
# Retrieving Results for index: 132, city: save
# ------------
# Retrieving Results for index: 133, city: cidreira
# ------------
# Retrieving Results for index: 134, city: nyurba
# ------------
# Retrieving Results for index: 135, city: kenai
# ------------
# Retrieving Results for index: 136, city: atuona
# ------------
# Retrieving Results for index: 137, city: cape town
# ------------
# Retrieving Results for index: 138, city: mandan
# ------------
# Retrieving Results for index: 139, city: norman wells
# ------------
# Retrieving Results for index: 140, city: antalaha
# ------------
# Retrieving Results for index: 141, city: padang
# ------------
# Retrieving Results for index: 142, city: kuryk
# ------------
# Retrieving Results for index: 143, city: igarka
# ------------
# Retrieving Results for index: 144, city: saldanha
# ------------
# Retrieving Results for index: 145, city: saint george
# ------------
# Retrieving Results for index: 146, city: kiunga
# ------------
# Retrieving Results for index: 147, city: vila velha
# ------------
# Retrieving Results for index: 148, city: starozhilovo
# ------------
# Retrieving Results for index: 149, city: kaitangata
# ------------
# Retrieving Results for index: 150, city: esperance
# ------------
# Retrieving Results for index: 151, city: muros
# ------------
# Retrieving Results for index: 152, city: high level
# ------------
# Retrieving Results for index: 153, city: tasbuget
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 154, city: mehamn
# ------------
# Retrieving Results for index: 155, city: bluff
# ------------
# Retrieving Results for index: 156, city: chumikan
# ------------
# Retrieving Results for index: 157, city: hamilton
# ------------
# Retrieving Results for index: 158, city: maldonado
# ------------
# Retrieving Results for index: 159, city: erdaojiang
# ------------
# Retrieving Results for index: 160, city: denpasar
# ------------
# Retrieving Results for index: 161, city: kuandian
# ------------
# Retrieving Results for index: 162, city: puerto pinasco
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 163, city: manta
# ------------
# Retrieving Results for index: 164, city: sangar
# ------------
# Retrieving Results for index: 165, city: vostochnyy
# ------------
# Retrieving Results for index: 166, city: yellowknife
# ------------
# Retrieving Results for index: 167, city: talnakh
# ------------
# Retrieving Results for index: 168, city: cururupu
# ------------
# Retrieving Results for index: 169, city: cherskiy
# ------------
# Retrieving Results for index: 170, city: bethel
# ------------
# Retrieving Results for index: 171, city: guangyuan
# ------------
# Retrieving Results for index: 172, city: husavik
# ------------
# Retrieving Results for index: 173, city: faya
# ------------
# Retrieving Results for index: 174, city: revuca
# ------------
# Retrieving Results for index: 175, city: arraial do cabo
# ------------
# Retrieving Results for index: 176, city: namibe
# ------------
# Retrieving Results for index: 177, city: skalistyy
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 178, city: lermontovka
# ------------
# Retrieving Results for index: 179, city: udachnyy
# ------------
# Retrieving Results for index: 180, city: namatanai
# ------------
# Retrieving Results for index: 181, city: kadykchan
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 182, city: torbay
# ------------
# Retrieving Results for index: 183, city: salekhard
# ------------
# Retrieving Results for index: 184, city: zolotinka
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 185, city: petatlan
# ------------
# Retrieving Results for index: 186, city: rundu
# ------------
# Retrieving Results for index: 187, city: port blair
# ------------
# Retrieving Results for index: 188, city: ilulissat
# ------------
# Retrieving Results for index: 189, city: pevek
# ------------
# Retrieving Results for index: 190, city: ambulu
# ------------
# Retrieving Results for index: 191, city: naudero
# ------------
# Retrieving Results for index: 192, city: chokurdakh
# ------------
# Retrieving Results for index: 193, city: linhares
# ------------
# Retrieving Results for index: 194, city: challapata
# ------------
# Retrieving Results for index: 195, city: erzin
# ------------
# Retrieving Results for index: 196, city: malanje
# ------------
# Retrieving Results for index: 197, city: lompoc
# ------------
# Retrieving Results for index: 198, city: tuktoyaktuk
# ------------
# Retrieving Results for index: 199, city: kalawit
# ------------
# Retrieving Results for index: 200, city: airai
# ------------
# Retrieving Results for index: 201, city: dunedin
# ------------
# Retrieving Results for index: 202, city: pasighat
# ------------
# Retrieving Results for index: 203, city: ponta do sol
# ------------
# Retrieving Results for index: 204, city: inderborskiy
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 205, city: itoman
# ------------
# Retrieving Results for index: 206, city: phan rang
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 207, city: qasigiannguit
# ------------
# Retrieving Results for index: 208, city: charters towers
# ------------
# Retrieving Results for index: 209, city: nizhneyansk
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 210, city: tiznit
# ------------
# Retrieving Results for index: 211, city: qandahar
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 212, city: san patricio
# ------------
# Retrieving Results for index: 213, city: tilichiki
# ------------
# Retrieving Results for index: 214, city: yabrud
# ------------
# Retrieving Results for index: 215, city: sentyabrskiy
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 216, city: emerald
# ------------
# Retrieving Results for index: 217, city: dzhebariki-khaya
# ------------
# Retrieving Results for index: 218, city: longyearbyen
# ------------
# Retrieving Results for index: 219, city: karamay
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 220, city: san jose
# ------------
# Retrieving Results for index: 221, city: key west
# ------------
# Retrieving Results for index: 222, city: houma
# ------------
# Retrieving Results for index: 223, city: westport
# ------------
# Retrieving Results for index: 224, city: alakurtti
# ------------
# Retrieving Results for index: 225, city: mayor pablo lagerenza
# ------------
# Retrieving Results for index: 226, city: chiquilistlan
# ------------
# Retrieving Results for index: 227, city: mao
# ------------
# Retrieving Results for index: 228, city: mutuipe
# ------------
# Retrieving Results for index: 229, city: geresk
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 230, city: illoqqortoormiut
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 231, city: wenshang
# ------------
# Retrieving Results for index: 232, city: rosetta
# ------------
# Retrieving Results for index: 233, city: progreso
# ------------
# Retrieving Results for index: 234, city: coquimbo
# ------------
# Retrieving Results for index: 235, city: kostino
# ------------
# Retrieving Results for index: 236, city: port-gentil
# ------------
# Retrieving Results for index: 237, city: buraydah
# ------------
# Retrieving Results for index: 238, city: homer
# ------------
# Retrieving Results for index: 239, city: jizan
# ------------
# Retrieving Results for index: 240, city: sao felix do xingu
# ------------
# Retrieving Results for index: 241, city: bom jesus
# ------------
# Retrieving Results for index: 242, city: victoria
# ------------
# Retrieving Results for index: 243, city: cabra
# ------------
# Retrieving Results for index: 244, city: iqaluit
# ------------
# Retrieving Results for index: 245, city: haines junction
# ------------
# Retrieving Results for index: 246, city: provideniya
# ------------
# Retrieving Results for index: 247, city: sohag
# ------------
# Retrieving Results for index: 248, city: ostrovnoy
# ------------
# Retrieving Results for index: 249, city: flin flon
# ------------
# Retrieving Results for index: 250, city: tsihombe
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 251, city: mogadishu
# ------------
# Retrieving Results for index: 252, city: aksarka
# ------------
# Retrieving Results for index: 253, city: rawannawi
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 254, city: georgetown
# ------------
# Retrieving Results for index: 255, city: nsanje
# ------------
# Retrieving Results for index: 256, city: lasa
# ------------
# Retrieving Results for index: 257, city: nishihara
# ------------
# Retrieving Results for index: 258, city: terra santa
# ------------
# Retrieving Results for index: 259, city: batagay
# ------------
# Retrieving Results for index: 260, city: hirara
# ------------
# Retrieving Results for index: 261, city: jabiru
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 262, city: lorengau
# ------------
# Retrieving Results for index: 263, city: namwala
# ------------
# Retrieving Results for index: 264, city: barrow
# ------------
# Retrieving Results for index: 265, city: abnub
# ------------
# Retrieving Results for index: 266, city: oranjemund
# ------------
# Retrieving Results for index: 267, city: troyes
# ------------
# Retrieving Results for index: 268, city: mar del plata
# ------------
# Retrieving Results for index: 269, city: kabare
# ------------
# Retrieving Results for index: 270, city: dhidhdhoo
# ------------
# Retrieving Results for index: 271, city: pueblo nuevo vinas
# ------------
# Retrieving Results for index: 272, city: el alto
# ------------
# Retrieving Results for index: 273, city: kodiak
# ------------
# Retrieving Results for index: 274, city: butaritari
# ------------
# Retrieving Results for index: 275, city: port hedland
# ------------
# Retrieving Results for index: 276, city: belmonte
# ------------
# Retrieving Results for index: 277, city: lyubeshiv
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 278, city: codrington
# ------------
# Retrieving Results for index: 279, city: balakhta
# ------------
# Retrieving Results for index: 280, city: hearst
# ------------
# Retrieving Results for index: 281, city: lensk
# ------------
# Retrieving Results for index: 282, city: viligili
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 283, city: burnie
# ------------
# Retrieving Results for index: 284, city: sola
# ------------
# Retrieving Results for index: 285, city: omboue
# ------------
# Retrieving Results for index: 286, city: tiksi
# ------------
# Retrieving Results for index: 287, city: antofagasta
# ------------
# Retrieving Results for index: 288, city: aksu
# ------------
# Retrieving Results for index: 289, city: mrirt
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 290, city: new norfolk
# ------------
# Retrieving Results for index: 291, city: rafai
# ------------
# Retrieving Results for index: 292, city: mount isa
# ------------
# Retrieving Results for index: 293, city: palabuhanratu
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 294, city: komsomolskiy
# ------------
# Retrieving Results for index: 295, city: obuasi
# ------------
# Retrieving Results for index: 296, city: solnechnyy
# ------------
# Retrieving Results for index: 297, city: pangnirtung
# ------------
# Retrieving Results for index: 298, city: bose
# ------------
# Retrieving Results for index: 299, city: tura
# ------------
# Retrieving Results for index: 300, city: kargil
# ------------
# Retrieving Results for index: 301, city: vila franca do campo
# ------------
# Retrieving Results for index: 302, city: rio gallegos
# ------------
# Retrieving Results for index: 303, city: margate
# ------------
# Retrieving Results for index: 304, city: gamba
# ------------
# Retrieving Results for index: 305, city: mount gambier
# ------------
# Retrieving Results for index: 306, city: jacmel
# ------------
# Retrieving Results for index: 307, city: tari
# ------------
# Retrieving Results for index: 308, city: agar
# ------------
# Retrieving Results for index: 309, city: rivadavia
# ------------
# Retrieving Results for index: 310, city: maniitsoq
# ------------
# Retrieving Results for index: 311, city: sao jose da coroa grande
# ------------
# Retrieving Results for index: 312, city: nome
# ------------
# Retrieving Results for index: 313, city: nguiu
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 314, city: skjervoy
# ------------
# Retrieving Results for index: 315, city: adrar
# ------------
# Retrieving Results for index: 316, city: pisco
# ------------
# Retrieving Results for index: 317, city: barentsburg
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 318, city: bilibino
# ------------
# Retrieving Results for index: 319, city: dauphin
# ------------
# Retrieving Results for index: 320, city: gat
# ------------
# Retrieving Results for index: 321, city: grand gaube
# ------------
# Retrieving Results for index: 322, city: granville
# ------------
# Retrieving Results for index: 323, city: san quintin
# ------------
# Retrieving Results for index: 324, city: praia
# ------------
# Retrieving Results for index: 325, city: comodoro rivadavia
# ------------
# Retrieving Results for index: 326, city: nassau
# ------------
# Retrieving Results for index: 327, city: nelson bay
# ------------
# Retrieving Results for index: 328, city: mutare
# ------------
# Retrieving Results for index: 329, city: guane
# ------------
# Retrieving Results for index: 330, city: coronel vivida
# ------------
# Retrieving Results for index: 331, city: sinnamary
# ------------
# Retrieving Results for index: 332, city: xining
# ------------
# Retrieving Results for index: 333, city: balozi
# ------------
# Retrieving Results for index: 334, city: saint-pierre
# ------------
# Retrieving Results for index: 335, city: brae
# ------------
# Retrieving Results for index: 336, city: seoul
# ------------
# Retrieving Results for index: 337, city: kachiry
# ------------
# Retrieving Results for index: 338, city: brasilia
# ------------
# Retrieving Results for index: 339, city: tekeli
# ------------
# Retrieving Results for index: 340, city: cockburn harbour
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 341, city: doha
# ------------
# Retrieving Results for index: 342, city: cochabamba
# ------------
# Retrieving Results for index: 343, city: olafsvik
# ------------
# Retrieving Results for index: 344, city: bintulu
# ------------
# Retrieving Results for index: 345, city: beringovskiy
# ------------
# Retrieving Results for index: 346, city: akyab
# ------------
# Retrieving Results for index: 347, city: ahipara
# ------------
# Retrieving Results for index: 348, city: poya
# ------------
# Retrieving Results for index: 349, city: anadyr
# ------------
# Retrieving Results for index: 350, city: brookhaven
# ------------
# Retrieving Results for index: 351, city: haibowan
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 352, city: coihaique
# ------------
# Retrieving Results for index: 353, city: hovd
# ------------
# Retrieving Results for index: 354, city: mabaruma
# ------------
# Retrieving Results for index: 355, city: hervey bay
# ------------
# Retrieving Results for index: 356, city: siderno
# ------------
# Retrieving Results for index: 357, city: vagur
# ------------
# Retrieving Results for index: 358, city: ruatoria
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 359, city: sahrak
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 360, city: am timan
# ------------
# Retrieving Results for index: 361, city: tabiauea
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 362, city: launceston
# ------------
# Retrieving Results for index: 363, city: college
# ------------
# Retrieving Results for index: 364, city: srikakulam
# ------------
# Retrieving Results for index: 365, city: port lincoln
# ------------
# Retrieving Results for index: 366, city: ibra
# ------------
# Retrieving Results for index: 367, city: villa constitucion
# ------------
# Retrieving Results for index: 368, city: pampierstad
# ------------
# Retrieving Results for index: 369, city: chase
# ------------
# Retrieving Results for index: 370, city: pakxe
# ------------
# Retrieving Results for index: 371, city: cherbourg
# ------------
# Retrieving Results for index: 372, city: punta alta
# ------------
# Retrieving Results for index: 373, city: northam
# ------------
# Retrieving Results for index: 374, city: catamarca
# ------------
# Retrieving Results for index: 375, city: that phanom
# ------------
# Retrieving Results for index: 376, city: alice springs
# ------------
# Retrieving Results for index: 377, city: hoquiam
# ------------
# Retrieving Results for index: 378, city: akure
# ------------
# Retrieving Results for index: 379, city: beatrice
# ------------
# Retrieving Results for index: 380, city: lamu
# ------------
# Retrieving Results for index: 381, city: sayyan
# ------------
# Retrieving Results for index: 382, city: caravelas
# ------------
# Retrieving Results for index: 383, city: zhangye
# ------------
# Retrieving Results for index: 384, city: gourdon
# ------------
# Retrieving Results for index: 385, city: burica
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 386, city: tondano
# ------------
# Retrieving Results for index: 387, city: kingaroy
# ------------
# Retrieving Results for index: 388, city: calituban
# ------------
# Retrieving Results for index: 389, city: lubango
# ------------
# Retrieving Results for index: 390, city: mpanda
# ------------
# Retrieving Results for index: 391, city: hami
# ------------
# Retrieving Results for index: 392, city: miyako
# ------------
# Retrieving Results for index: 393, city: nobeoka
# ------------
# Retrieving Results for index: 394, city: poroshkovo
# ------------
# Retrieving Results for index: 395, city: linxia
# ------------
# Retrieving Results for index: 396, city: elizabeth city
# ------------
# Retrieving Results for index: 397, city: prabumulih
# ------------
# Retrieving Results for index: 398, city: yar-sale
# ------------
# Retrieving Results for index: 399, city: bonfim
# ------------
# Retrieving Results for index: 400, city: tres picos
# ------------
# Retrieving Results for index: 401, city: inhambane
# ------------
# Retrieving Results for index: 402, city: mys shmidta
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 403, city: mackay
# ------------
# Retrieving Results for index: 404, city: eyl
# ------------
# Retrieving Results for index: 405, city: sarh
# ------------
# Retrieving Results for index: 406, city: buala
# ------------
# Retrieving Results for index: 407, city: churapcha
# ------------
# Retrieving Results for index: 408, city: amderma
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 409, city: ulaangom
# ------------
# Retrieving Results for index: 410, city: ossora
# ------------
# Retrieving Results for index: 411, city: yangjiang
# ------------
# Retrieving Results for index: 412, city: doctor pedro p. pena
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 413, city: tamworth
# ------------
# Retrieving Results for index: 414, city: zeya
# ------------
# Retrieving Results for index: 415, city: luderitz
# ------------
# Retrieving Results for index: 416, city: dongsheng
# ------------
# Retrieving Results for index: 417, city: roquetas de mar
# ------------
# Retrieving Results for index: 418, city: alamosa
# ------------
# Retrieving Results for index: 419, city: wieliczka
# ------------
# Retrieving Results for index: 420, city: viedma
# ------------
# Retrieving Results for index: 421, city: lavrentiya
# ------------
# Retrieving Results for index: 422, city: bengkulu
# ------------
# Retrieving Results for index: 423, city: carupano
# ------------
# Retrieving Results for index: 424, city: aklavik
# ------------
# Retrieving Results for index: 425, city: sorland
# ------------
# Retrieving Results for index: 426, city: bukama
# ------------
# Retrieving Results for index: 427, city: kangaatsiaq
# ------------
# Retrieving Results for index: 428, city: marawi
# ------------
# Retrieving Results for index: 429, city: hillsborough
# ------------
# Retrieving Results for index: 430, city: belushya guba
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 431, city: seydi
# ------------
# Retrieving Results for index: 432, city: wilmington
# ------------
# Retrieving Results for index: 433, city: sitka
# ------------
# Retrieving Results for index: 434, city: timbiqui
# ------------
# Retrieving Results for index: 435, city: siocon
# ------------
# Retrieving Results for index: 436, city: roma
# ------------
# Retrieving Results for index: 437, city: usinsk
# ------------
# Retrieving Results for index: 438, city: halalo
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 439, city: awjilah
# ------------
# Retrieving Results for index: 440, city: dubrajpur
# ------------
# Retrieving Results for index: 441, city: bur gabo
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 442, city: longyan
# ------------
# Retrieving Results for index: 443, city: wattegama
# ------------
# Retrieving Results for index: 444, city: schneverdingen
# ------------
# Retrieving Results for index: 445, city: longhua
# ------------
# Retrieving Results for index: 446, city: oyama
# ------------
# Retrieving Results for index: 447, city: gillette
# ------------
# Retrieving Results for index: 448, city: shingu
# ------------
# Retrieving Results for index: 449, city: pedernales
# ------------
# Retrieving Results for index: 450, city: kahului
# ------------
# Retrieving Results for index: 451, city: noyabrsk
# ------------
# Retrieving Results for index: 452, city: tashtagol
# ------------
# Retrieving Results for index: 453, city: narsaq
# ------------
# Retrieving Results for index: 454, city: aksha
# ------------
# Retrieving Results for index: 455, city: fukue
# ------------
# Retrieving Results for index: 456, city: ust-tarka
# ------------
# Retrieving Results for index: 457, city: moussoro
# ------------
# Retrieving Results for index: 458, city: taicheng
# ------------
# Retrieving Results for index: 459, city: souillac
# ------------
# Retrieving Results for index: 460, city: dukat
# ------------
# Retrieving Results for index: 461, city: kaeo
# ------------
# Retrieving Results for index: 462, city: rincon
# ------------
# Retrieving Results for index: 463, city: washougal
# ------------
# Retrieving Results for index: 464, city: port hardy
# ------------
# Retrieving Results for index: 465, city: lakes entrance
# ------------
# Retrieving Results for index: 466, city: weinan
# ------------
# Retrieving Results for index: 467, city: grand river south east
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 468, city: sungairaya
# ------------
# Retrieving Results for index: 469, city: yerbogachen
# ------------
# Retrieving Results for index: 470, city: leningradskiy
# ------------
# Retrieving Results for index: 471, city: egvekinot
# ------------
# Retrieving Results for index: 472, city: mlowo
# ------------
# Retrieving Results for index: 473, city: kulhudhuffushi
# ------------
# Retrieving Results for index: 474, city: alyangula
# ------------
# Retrieving Results for index: 475, city: mezen
# ------------
# Retrieving Results for index: 476, city: rameswaram
# ------------
# Retrieving Results for index: 477, city: okha
# ------------
# Retrieving Results for index: 478, city: kirovskaya
# ------------
# Retrieving Results for index: 479, city: bonthe
# ------------
# Retrieving Results for index: 480, city: wamba
# ------------
# Retrieving Results for index: 481, city: acapulco
# ------------
# Retrieving Results for index: 482, city: bonavista
# ------------
# Retrieving Results for index: 483, city: lucapa
# ------------
# Retrieving Results for index: 484, city: mentok
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 485, city: jiayuguan
# ------------
# Retrieving Results for index: 486, city: fort frances
# ------------
# Retrieving Results for index: 487, city: novomikhaylovskiy
# ------------
# Retrieving Results for index: 488, city: goiatuba
# ------------
# Retrieving Results for index: 489, city: jacareacanga
# ------------
# Retrieving Results for index: 490, city: praxedis guerrero
# ------------
# Retrieving Results for index: 491, city: pacific grove
# ------------
# Retrieving Results for index: 492, city: storm lake
# ------------
# Retrieving Results for index: 493, city: palimbang
# ------------
# Retrieving Results for index: 494, city: gao
# ------------
# Retrieving Results for index: 495, city: nicoya
# ------------
# Retrieving Results for index: 496, city: korla
# ------------
# Retrieving Results for index: 497, city: tuggurt
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 498, city: songkhla
# ------------
# Retrieving Results for index: 499, city: karaul
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 500, city: busembatia
# ------------
# Retrieving Results for index: 501, city: kuche
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 502, city: cody
# ------------
# Retrieving Results for index: 503, city: chapais
# ------------
# Retrieving Results for index: 504, city: pimentel
# ------------
# Retrieving Results for index: 505, city: vestmanna
# ------------
# Retrieving Results for index: 506, city: roald
# ------------
# Retrieving Results for index: 507, city: puerto del rosario
# ------------
# Retrieving Results for index: 508, city: suntar
# ------------
# Retrieving Results for index: 509, city: nanning
# ------------
# Retrieving Results for index: 510, city: birjand
# ------------
# Retrieving Results for index: 511, city: leshukonskoye
# ------------
# Retrieving Results for index: 512, city: flinders
# ------------
# Retrieving Results for index: 513, city: marcona
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 514, city: zaysan
# ------------
# Retrieving Results for index: 515, city: qaqortoq
# ------------
# Retrieving Results for index: 516, city: anloga
# ------------
# Retrieving Results for index: 517, city: santander jimenez
# ------------
# Retrieving Results for index: 518, city: vardo
# ------------
# Retrieving Results for index: 519, city: smithers
# ------------
# Retrieving Results for index: 520, city: kuzovatovo
# ------------
# Retrieving Results for index: 521, city: ada
# ------------
# Retrieving Results for index: 522, city: muhoroni
# ------------
# Retrieving Results for index: 523, city: abrau-dyurso
# ------------
# Retrieving Results for index: 524, city: meyungs
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 525, city: quyquyho
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 526, city: saint-augustin
# ------------
# Retrieving Results for index: 527, city: machinga
# ------------
# Retrieving Results for index: 528, city: oistins
# ------------
# Retrieving Results for index: 529, city: yulara
# ------------
# Retrieving Results for index: 530, city: sobolevo
# ------------
# Retrieving Results for index: 531, city: figline valdarno
# ------------
# Retrieving Results for index: 532, city: sibolga
# ------------
# Retrieving Results for index: 533, city: cayenne
# ------------
# Retrieving Results for index: 534, city: mosetse
# ------------
# Retrieving Results for index: 535, city: vestmannaeyjar
# ------------
# Retrieving Results for index: 536, city: la ronge
# ------------
# Retrieving Results for index: 537, city: jiexiu
# ------------
# Retrieving Results for index: 538, city: koutiala
# ------------
# Retrieving Results for index: 539, city: hun
# ------------
# Retrieving Results for index: 540, city: limoncito
# ------------
# Retrieving Results for index: 541, city: alotau
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 542, city: shache
# ------------
# Retrieving Results for index: 543, city: nabire
# ------------
# Retrieving Results for index: 544, city: fershampenuaz
# ------------
# Retrieving Results for index: 545, city: kon tum
# ------------
# Retrieving Results for index: 546, city: libreville
# ------------
# Retrieving Results for index: 547, city: pokrovsk-uralskiy
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 548, city: moerai
# ------------
# Retrieving Results for index: 549, city: nuuk
# ------------
# Retrieving Results for index: 550, city: esil
# ------------
# Retrieving Results for index: 551, city: tumannyy
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 552, city: bilma
# ------------
# Retrieving Results for index: 553, city: severodvinsk
# ------------
# Retrieving Results for index: 554, city: sarangani
# ------------
# Retrieving Results for index: 555, city: bolobo
# ------------
# Retrieving Results for index: 556, city: kozmodemyansk
# ------------
# Retrieving Results for index: 557, city: san andres
# ------------
# Retrieving Results for index: 558, city: vanimo
# ------------
# Retrieving Results for index: 559, city: yuncheng
# ------------
# Retrieving Results for index: 560, city: sainte-marie
# ------------
# Retrieving Results for index: 561, city: hihifo
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 562, city: washington
# ------------
# Retrieving Results for index: 563, city: fort dix
# ------------
# Retrieving Results for index: 564, city: atar
# ------------
# Retrieving Results for index: 565, city: jibuti
# ------------
# Retrieving Results for index: 566, city: samandag
# ------------
# Retrieving Results for index: 567, city: lanzhou
# ------------
# Retrieving Results for index: 568, city: zalantun
# ------------
# Retrieving Results for index: 569, city: matay
# ------------
# Retrieving Results for index: 570, city: gualaquiza
# ------------
# Retrieving Results for index: 571, city: rio grande
# ------------
# Retrieving Results for index: 572, city: constitucion
# ------------
# Retrieving Results for index: 573, city: cockburn town
# ------------
# Retrieving Results for index: 574, city: tazmalt
# ------------
# Retrieving Results for index: 575, city: kasane
# ------------
# Retrieving Results for index: 576, city: cabedelo
# ------------
# Retrieving Results for index: 577, city: kamenskoye
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 578, city: elko
# ------------
# Retrieving Results for index: 579, city: sorvag
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 580, city: upata
# ------------
# Retrieving Results for index: 581, city: pombal
# ------------
# Retrieving Results for index: 582, city: chabahar
# ------------
# Retrieving Results for index: 583, city: charlestown
# ------------
# Retrieving Results for index: 584, city: road town
# ------------
# Retrieving Results for index: 585, city: bandarbeyla
# ------------
# Retrieving Results for index: 586, city: les cayes
# ------------
# Retrieving Results for index: 587, city: gorele
# ------------
# Retrieving Results for index: 588, city: camacupa
# ------------
# Retrieving Results for index: 589, city: harper
# ------------
# Retrieving Results for index: 590, city: kone
# ------------
# Retrieving Results for index: 591, city: rawson
# ------------
# Retrieving Results for index: 592, city: onokhoy
# ------------
# Retrieving Results for index: 593, city: polis
# ------------
# Retrieving Results for index: 594, city: havelock
# ------------
# Retrieving Results for index: 595, city: surin
# ------------
# Retrieving Results for index: 596, city: auch
# ------------
# Retrieving Results for index: 597, city: biak
# ------------
# Retrieving Results for index: 598, city: quelimane
# ------------
# Retrieving Results for index: 599, city: wulanhaote
# City Not Found... skipping.
# ------------
# Retrieving Results for index: 600, city: denia
# ------------
# Retrieving Results for index: 601, city: makakilo city
# ------------
# Retrieving Results for index: 602, city: pitimbu
# ------------
# Retrieving Results for index: 603, city: pochutla
# ------------
# Retrieving Results for index: 604, city: yelan-kolenovskiy
# ------------
# Retrieving Results for index: 605, city: lagoa
# ------------
# Retrieving Results for index: 606, city: talakan
# ------------
# Retrieving Results for index: 607, city: bronnoysund
# ------------
# Retrieving Results for index: 608, city: honiara
# ------------
# Retrieving Results for index: 609, city: chicama
# ------------
# Retrieving Results for index: 610, city: tautira
# ------------
# Retrieving Results for index: 611, city: meulaboh
# ------------
# Retrieving Results for index: 612, city: ayan
# ------------
# Retrieving Results for index: 613, city: dabola
# ------------
# Retrieving Results for index: 614, city: puerto quijarro
# ------------
# Retrieving Results for index: 615, city: taltal
# ------------
# Retrieving Results for index: 616, city: aitape
# ------------
# Retrieving Results for index: 617, city: laguna
# ------------
# Retrieving Results for index: 618, city: dhali
# ------------
# Retrieving Results for index: 619, city: huilong
# ------------
# Retrieving Results for index: 620, city: dawei
# ------------
# Retrieving Results for index: 621, city: mehran
# ------------

# %%
# Ensure dataframe is being populated correctly.
# Note: Cities not found will not be populated. Corresponding indices will be removed in the next step.
city_weather_df.head()
# Out:
#             City      City Name Country     Lng    Lat Max Temp (F)  \
# 0  alta floresta  Alta Floresta      BR  -56.09  -9.88         89.6
# 1      saskylakh      Saskylakh      RU  114.08  71.92        11.32
# 2   punta arenas   Punta Arenas      CL  -70.92 -53.15         48.2
# 3        wanning        Wanning      CN   110.4   18.8        74.64
# 4       zhigansk       Zhigansk      RU  123.37  66.77        20.55
#
#   Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0           52             20            10.29
# 1           95             88             4.56
# 2           76             40             9.17
# 3           87             19             6.82
# 4           97            100             7.99

# %%
# Ensure all items are in dataframe
len(city_weather_df.index)
# Out:
# 622

# %%
# Remove cities that were not found in the OpenWeather query
city_weather_df = city_weather_df[city_weather_df["City Name"] != ""]
city_weather_df.head()
# Out:
#             City      City Name Country     Lng    Lat Max Temp (F)  \
# 0  alta floresta  Alta Floresta      BR  -56.09  -9.88         89.6
# 1      saskylakh      Saskylakh      RU  114.08  71.92        11.32
# 2   punta arenas   Punta Arenas      CL  -70.92 -53.15         48.2
# 3        wanning        Wanning      CN   110.4   18.8        74.64
# 4       zhigansk       Zhigansk      RU  123.37  66.77        20.55
#
#   Humidity (%) Cloudiness (%) Wind Speed (mph)
# 0           52             20            10.29
# 1           95             88             4.56
# 2           76             40             9.17
# 3           87             19             6.82
# 4           97            100             7.99

# %%
# Ensure empty rows were removed
len(city_weather_df.index)
# Out:
# 565

# %% [markdown]
# ### Export data frame into CSV

# %%
# Add dependincies
import os

# Exporting rertrieved data to CSV (to avoid making another resource consuming request)
output =  os.path.join("output_data","cities.csv")

# If the Output folder does not exist, create it; if it does, use it!
os.makedirs(os.path.dirname(output), exist_ok=True)

# Write output to csv file and close it when done
city_weather_df.to_csv(output)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
# Create a scatter plot function
def weather_scat(title,x_term,y_term,x_label,y_label,color):
    t = time.localtime()
    current_time = time.strftime("%b %d %Y %H:%M:%S", t)
    x_series = city_weather_df[x_term]
    y_series = city_weather_df[y_term]
    plt.scatter(x_series,
                y_series,
                marker="o",
                edgecolors='black',
                color = color
               )
    plt.title(f"{title}\n({current_time})",fontweight="bold")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.grid(alpha = 0.25)
    plt.savefig("output_data/"+title+".png")

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plot_title = "City Latitude vs. MAX Temperature (deg F)"

weather_scat(plot_title,
             "Lat",
             "Max Temp (F)",
             "latitude (deg)",
             "maximum temperature (deg F)",
             "coral")
plt.show()

# %% [markdown]
# ##### <font color = blue>This plot shows that hotter temperatures occur near the equator and tropics, getting colder around the poles (closer to +90, -90 deg lattitude)</font>

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plot_title = "City Latitude vs. Humidity (%)"

weather_scat(plot_title,
             "Lat",
             "Humidity (%)",
             "latitude (deg)",
             "humidity (%)",
             "LightBlue")
plt.show()

# %% [markdown]
# ##### <font color = blue>This plot shows a small cluster of high humidity occuring at the equator and at a latitude = 65 deg</font>

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plot_title = "City Latitude vs. Cloudiness (%)"

weather_scat(plot_title,
             "Lat",
             "Cloudiness (%)",
             "latitude (deg)",
             "cloudiness (%)",
             "LightGreen")
plt.show()

# %% [markdown]
# ##### <font color = blue>This plot shows how cloudiness is not predicatable by city latitude</font>

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plot_title = "City Latitude vs. Wind Speed (mph)"

weather_scat(plot_title,
             "Lat",
             "Wind Speed (mph)",
             "latitude (deg)",
             "wind speed (mph)",
             "orange")
plt.show()

# %% [markdown]
# ##### <font color = blue>This plot shows that the average wind speed around the world is between 0 to 10 mph</font>

# %% [markdown]
# ## Linear Regression

# %%
# Load data set
city_weather_df = pd.read_csv("../WeatherPy/output_data/cities.csv",index_col=0)
city_weather_df.head()
# Out:
#    Unnamed: 0.1           City      City Name Country     Lng    Lat  \
# 0             0  alta floresta  Alta Floresta      BR  -56.09  -9.88
# 1             1      saskylakh      Saskylakh      RU  114.08  71.92
# 2             2   punta arenas   Punta Arenas      CL  -70.92 -53.15
# 3             3        wanning        Wanning      CN  110.40  18.80
# 4             4       zhigansk       Zhigansk      RU  123.37  66.77
#
#    Max Temp (F)  Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0         89.60          52.0            20.0             10.29
# 1         11.32          95.0            88.0              4.56
# 2         48.20          76.0            40.0              9.17
# 3         74.64          87.0            19.0              6.82
# 4         20.55          97.0           100.0              7.99

# %%
# Create a function to create Linear Regression plots
def make_regress_plots(title,x_term,y_term,x_label,y_label,x_annotate,y_annotate):
    t = time.localtime()
    current_time = time.strftime("%b %d %Y %H:%M:%S", t)
    x_values = x_term
    y_values = y_term
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept

    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,
                y_values,
                marker="o",
                color="lightslategrey",
                alpha = 0.5)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,(x_annotate,y_annotate),fontsize=15,color="red")
    plt.title(f"{title}\n{current_time}\n($r^2$ = {round(rvalue**2,5)})",fontweight="bold")
    plt.grid()
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.savefig("output_data/"+title+".png")

# %%
# Create Northern and Southern Hemisphere DataFrames
north_hemi = city_weather_df.loc[city_weather_df["Lat"] > 0]
south_hemi = city_weather_df.loc[city_weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
title ="Northern Hemisphere - Max Temp (F) vs. City Latitude"
make_regress_plots(title,
                   north_hemi["Lat"],
                   north_hemi["Max Temp (F)"],
                   "city latitude (deg)",
                   "max temperature (deg F)",
                   5,
                   10
                  )
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
title ="Southern Hemisphere - Max Temp (F) vs. City Latitude"
make_regress_plots(title,
                   south_hemi["Lat"],
                   south_hemi["Max Temp (F)"],
                   "city latitude (deg)",
                   "max temperature (deg F)",
                   -50,
                   85
                  )
plt.show()

# %% [markdown]
# ##### <font color = blue>The plots above show that a city's max temperature is strongly correlated to its geographical latitude in the northern hemisphere, and moderately correlated in the southern hemisphere. The farther you move away from the equator, the cooler the temperatures get.</font>

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
title ="Northern Hemisphere - Humidity (%) vs. City Latitude"
make_regress_plots(title,
                   north_hemi["Lat"],
                   north_hemi["Humidity (%)"],
                   "city latitude (deg)",
                   "humidity (%)",
                   45,
                   10
                  )
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
title ="Southern Hemisphere - Humidity (%) vs. City Latitude"
make_regress_plots(title,
                   south_hemi["Lat"],
                   south_hemi["Humidity (%)"],
                   "city latitude (deg)",
                   "humidity (%)",
                   -55,
                   10
                  )
plt.show()

# %% [markdown]
# ##### <font color = blue>The plots above show that a city's humidity is not correlated to its geographical latitude.</font>
#
# ##### <font color = blue>From the regression lines, humidity slightly increases in the northern hemisphere away from the equator. In the southern hemishere, the opposite is observed, with himidity slightly decreasing as you move towards the south pole.</font>

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
title ="Northern Hemisphere - Cloudiness (%) vs. City Latitude"
make_regress_plots(title,
                   north_hemi["Lat"],
                   north_hemi["Cloudiness (%)"],
                   "city latitude (deg)",
                   "cloudiness (%)",
                   25,
                   30
                  )
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
title ="Southern Hemisphere - Cloudiness (%) vs. City Latitude"
make_regress_plots(title,
                   south_hemi["Lat"],
                   south_hemi["Cloudiness (%)"],
                   "city latitude (deg)",
                   "cloudiness (%)",
                   -55,
                   45
                  )
plt.show()

# %% [markdown]
# ##### <font color = blue>The plots above show that a city's level of cloudiness is not correlated to its geographical latitude.</font>
#
# ##### <font color = blue>From the regression lines, in both northern and southern hemispheres, cities are less cloudy as their latitude near the equator.</font>

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
title ="Northern Hemisphere - Wind Speed (mph) vs. City Latitude"
make_regress_plots(title,
                   north_hemi["Lat"],
                   north_hemi["Wind Speed (mph)"],
                   "city latitude (deg)",
                   "wind speed (rpm)",
                   45,
                   27
                  )
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
title ="Southern Hemisphere - Wind Speed (mph) vs. City Latitude"
make_regress_plots(title,
                   south_hemi["Lat"],
                   south_hemi["Wind Speed (mph)"],
                   "city latitude (deg)",
                   "wind speed (rpm)",
                   -25,
                   26
                  )
plt.show()

# %% [markdown]
# ##### <font color = blue>The plots above show that a city's wind speed is not correlated to its geographical latitude.</font>
#
# ##### <font color = blue>From the regression lines, cities in the southern hemisphere do observe an increase in wind speeds as they move away from the equator.</font>
